# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
df_front_end=pd.read_csv('from_end.csv')
df_data_science=pd.read_csv('data_science_salary.csv')
df_back_end=pd.read_csv('back_end.csv')
df_web_deb=pd.read_csv('web_dev.csv')
df_quant=pd.read_csv('quant.csv')
plt.rcdefaults()

# %%
df_quant.sample(10)['salary']
# Out:
# 1415               $84,074 a year
# 1104     $52,495 - $72,210 a year
# 1060      $26.00 - $35.10 an hour
# 62       $51,808 - $85,484 a year
# 956       $26.00 - $35.10 an hour
# 1467     $58,672 - $92,281 a year
# 1372    $64,948 - $133,465 a year
# 602      $59,534 - $77,396 a year
# 1138     $52,495 - $72,210 a year
# 1812               $84,074 a year
# Name: salary, dtype: object

# %%
list_median=[]

# %%
def get_salary_range(salary_string):
    '''
    return a range
    '''
    d=dict()
    l=salary_string.split(' ')
#     if l[0]=='Up':
#         return None
    Type=l[-1]
    Types=['hour','day','week','month','year'] # h='$18 - $30 an hour'
    if Type in Types:
        min= float(l[0].replace(',','').split('$')[1])
        max= float(l[2].replace(',','').split('$')[1])
    d['mean']=(min+max)/2
    d['type']=Type
    d['min']=min
    d['max']=max
    return d

# %%
def get_salary_value(salary_string):
    '''
    return the value
    '''
    d=dict()
    l=salary_string.split(' ')
#     if l[0]=='Up':
#         return None
    Type=l[-1]
    Types=['hour','day','week','month','year']
    if Type in Types:
        #mean= float(l[0].split('$')[1].replace(',',''))
        mean= float(l[0].replace(',','').split('$')[1])
    d['mean']=mean
    d['type']=Type
    d['min']=None
    d['max']=None
    return d

# %%
def get_salary(salary_string):
    print(salary_string)
    if '-' in salary_string: # 8,750− 9,167 a month
        '''
        its a range
        '''
        return get_salary_range(salary_string)
    elif len(salary_string.split(' '))==3:
        '''
        only a value
        '''
        return get_salary_value(salary_string)
    else:
        return None

# %%
def standardized(salary_string):
    if type(salary_string)!=str:
        return None
    if salary_string.strip()[0]!='$':
        return None
    d=get_salary(salary_string)
    if d==None:
        return None
    if d['type']=='hour':
        return d['mean']*40*52
    elif d['type']=='day':
        return d['mean']*5*52
    elif d['type']=='week':
        return d['mean']*52
    elif d['type']=='month':
        return d['mean']*12
    elif d['type']=='year':
        return d['mean']
    else:
        return None

# %%
df2=df_quant.loc[filt]
df2['salary']
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-456-c2d2fd6fd676> in <module>
# ----> 1 df2=df_quant.loc[filt]
#       2 df2['salary']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1867             return self._get_slice_axis(key, axis=axis)
#    1868         elif com.is_bool_indexer(key):
# -> 1869             return self._getbool_axis(key, axis=axis)
#    1870         elif is_list_like_indexer(key):
#    1871
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getbool_axis(self, key, axis)
#    1513             axis = self.axis or 0
#    1514         labels = self.obj._get_axis(axis)
# -> 1515         key = check_bool_indexer(labels, key)
#    1516         inds, = key.nonzero()
#    1517         try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in check_bool_indexer(ax, key)
#    2484         mask = isna(result._values)
#    2485         if mask.any():
# -> 2486             raise IndexingError('Unalignable boolean Series provided as '
#    2487                                 'indexer (index of the boolean Series and of '
#    2488                                 'the indexed object do not match')
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match

# %%
df2['Salary_quant']=df2['salary'].map(standardized)
# Out:
# $49,381 - $72,860 a year
# $87,703 - $113,002 a year
# $49,381 - $72,860 a year
# $54,142 - $89,315 a year
# $145,000 - $225,000 a year
# $64,948 - $133,465 a year
# $81,931 a year
# $64,948 - $133,465 a year
# $100,000 - $150,000 a year
# $81,931 a year
# $67,968 - $126,062 a year
# $150,000 - $170,000 a year
# $150,000 - $170,000 a year
# $100,000 - $150,000 a year
# $60 an hour
# $85,000 - $90,000 a year
# $64,948 - $133,465 a year
# $73,052 - $148,967 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $60,000 a year
# $64,948 - $133,465 a year
# $75 an hour
# $64,948 - $133,465 a year
# $75 an hour
# $60,000 a year
# $64,948 - $133,465 a year
# $60,000 a year
# $60,000 a year
# $75 an hour
# $60,000 a year
# $64,948 - $133,465 a year
# $75 an hour
# $75 an hour
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $60,000 a year
# $64,948 - $133,465 a year
# $60,000 a year
# $75 an hour
# $75 an hour
# $75 an hour
# $60,000 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $75 an hour
# $75 an hour
# $75 an hour
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $60,000 a year
# $60,000 a year
# $75 an hour
# $75 an hour
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $60,000 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $60,000 a year
# $64,948 - $133,465 a year
# $75 an hour
# $60,000 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $60,000 a year
# $60,000 a year
# $75 an hour
# $60,000 a year
# $75 an hour
# $60,000 a year
# $64,948 - $133,465 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $75 an hour
# $64,948 - $133,465 a year
# $75 an hour
# $60,000 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $75 an hour
# $64,948 - $133,465 a year
# $60,000 a year
# $64,948 - $133,465 a year
# $75 an hour
# $75 an hour
# $64,948 - $133,465 a year
# $75 an hour
# $64,948 - $133,465 a year
# $75 an hour
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $75 an hour
# $60,000 a year
# $75 an hour
# $75 an hour
# $64,948 - $133,465 a year
# $75 an hour
# $64,948 - $133,465 a year
# $75 an hour
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $60,000 a year
# $64,948 - $133,465 a year
# $75 an hour
# $60,000 a year
# $64,948 - $133,465 a year
# $75 an hour
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year

# %%
df2
# Out:
#                                   position  \
# 2    Data Science and Analytics Specialist
# 3                      Data Scientist\nnew
# 4    Data Science and Analytics Specialist
# 6                   Data Scientist II\nnew
# 13                     Data Scientist\nnew
# 17                          Data Scientist
# 19            Data Engineer/ ETL Developer
# 23                          Data Scientist
# 24                           Data Engineer
# 28            Data Engineer/ ETL Developer
# 29                          Data Scientist
# 30                           Data Engineer
# 31                           Data Engineer
# 32                           Data Engineer
# 34            Data Scientist (Health Care)
# 37            Data Science Instructor\nnew
# 40                            Data Analyst
# 41                           Data Engineer
# 43                            Data Analyst
# 45                            Data Analyst
# 47                            Data Analyst
# 48                           Data Engineer
# 50                            Data Analyst
# 51             Data Visualization Engineer
# 53                            Data Analyst
# 54             Data Visualization Engineer
# 55                           Data Engineer
# 57                            Data Analyst
# 58                           Data Engineer
# 60                           Data Engineer
# ..                                     ...
# 267                          Data Engineer
# 268                          Data Engineer
# 269                          Data Engineer
# 270                          Data Engineer
# 271                          Data Engineer
# 272                          Data Engineer
# 273                          Data Engineer
# 274                          Data Engineer
# 277                          Data Engineer
# 280                          Data Engineer
# 281                          Data Engineer
# 283                          Data Engineer
# 284                          Data Engineer
# 287                          Data Engineer
# 293                          Data Engineer
# 294                          Data Engineer
# 296                          Data Engineer
# 298                          Data Engineer
# 300                          Data Engineer
# 302                          Data Engineer
# 308                          Data Engineer
# 311                          Data Engineer
# 314                          Data Engineer
# 318                          Data Engineer
# 320                          Data Engineer
# 321                          Data Engineer
# 322                          Data Engineer
# 323                          Data Engineer
# 329                          Data Engineer
# 330                          Data Engineer
#
#                                                company  \
# 2                              Chesterfield County, VA
# 3               Government of the District of Columbia
# 4                              Chesterfield County, VA
# 6                               University of Kentucky
# 13                                          Triplebyte
# 17                            US Department of Defense
# 19                                         SDH Systems
# 23                            US Department of Defense
# 24                                 Blue Orange Digital
# 28                                         SDH Systems
# 29     US Other Agencies and Independent Organizations
# 30                                              Alldus
# 31                                              Alldus
# 32                                 Blue Orange Digital
# 34                                       Ace-stack LLC
# 37   Research Foundation of The City University of ...
# 40                            US Department of Defense
# 41                         Central Intelligence Agency
# 43                            US Department of Defense
# 45                            US Department of Defense
# 47                            US Department of Defense
# 48                                           Kognetics
# 50                            US Department of Defense
# 51                                       Ace-stack LLC
# 53                            US Department of Defense
# 54                                       Ace-stack LLC
# 55                                           Kognetics
# 57                            US Department of Defense
# 58                                           Kognetics
# 60                                           Kognetics
# ..                                                 ...
# 267                                          Kognetics
# 268                                          Kognetics
# 269                                          Kognetics
# 270                                          Kognetics
# 271                                          Kognetics
# 272                                          Kognetics
# 273                                          Kognetics
# 274                                          Kognetics
# 277                                          Kognetics
# 280                                          Kognetics
# 281                                          Kognetics
# 283                                          Kognetics
# 284                                          Kognetics
# 287                                          Kognetics
# 293                                          Kognetics
# 294                                          Kognetics
# 296                                          Kognetics
# 298                                          Kognetics
# 300                                          Kognetics
# 302                                          Kognetics
# 308                                          Kognetics
# 311                                          Kognetics
# 314                                          Kognetics
# 318                                          Kognetics
# 320                                          Kognetics
# 321                                          Kognetics
# 322                                          Kognetics
# 323                                          Kognetics
# 329                                          Kognetics
# 330                                          Kognetics
#
#                                        location                      salary  \
# 2                              Chesterfield, VA    $49,381 - $72,860 a year
# 3    Washington, DC 20002 (Truxton Circle area)   $87,703 - $113,002 a year
# 4                              Chesterfield, VA    $49,381 - $72,860 a year
# 6                                 Lexington, KY    $54,142 - $89,315 a year
# 13                                  Seattle, WA  $145,000 - $225,000 a year
# 17                                St. Louis, MO   $64,948 - $133,465 a year
# 19                Chicago, IL 60604 (Loop area)              $81,931 a year
# 23                                St. Louis, MO   $64,948 - $133,465 a year
# 24         Alexandria, VA 22314 (Old Town area)  $100,000 - $150,000 a year
# 28                Chicago, IL 60604 (Loop area)              $81,931 a year
# 29                               Washington, DC   $67,968 - $126,062 a year
# 30                                 New York, NY  $150,000 - $170,000 a year
# 31                                 New York, NY  $150,000 - $170,000 a year
# 32         Alexandria, VA 22314 (Old Town area)  $100,000 - $150,000 a year
# 34                               Washington, DC                 $60 an hour
# 37                                 New York, NY    $85,000 - $90,000 a year
# 40                                St. Louis, MO   $64,948 - $133,465 a year
# 41                               Washington, DC   $73,052 - $148,967 a year
# 43                                St. Louis, MO   $64,948 - $133,465 a year
# 45                                St. Louis, MO   $64,948 - $133,465 a year
# 47                                St. Louis, MO   $64,948 - $133,465 a year
# 48                                  Gahanna, OH              $60,000 a year
# 50                                St. Louis, MO   $64,948 - $133,465 a year
# 51                                  Seattle, WA                 $75 an hour
# 53                                St. Louis, MO   $64,948 - $133,465 a year
# 54                                  Seattle, WA                 $75 an hour
# 55                                  Gahanna, OH              $60,000 a year
# 57                                St. Louis, MO   $64,948 - $133,465 a year
# 58                                  Gahanna, OH              $60,000 a year
# 60                                  Gahanna, OH              $60,000 a year
# ..                                          ...                         ...
# 267                                 Gahanna, OH              $60,000 a year
# 268                                 Gahanna, OH              $60,000 a year
# 269                                 Gahanna, OH              $60,000 a year
# 270                                 Gahanna, OH              $60,000 a year
# 271                                 Gahanna, OH              $60,000 a year
# 272                                 Gahanna, OH              $60,000 a year
# 273                                 Gahanna, OH              $60,000 a year
# 274                                 Gahanna, OH              $60,000 a year
# 277                                 Gahanna, OH              $60,000 a year
# 280                                 Gahanna, OH              $60,000 a year
# 281                                 Gahanna, OH              $60,000 a year
# 283                                 Gahanna, OH              $60,000 a year
# 284                                 Gahanna, OH              $60,000 a year
# 287                                 Gahanna, OH              $60,000 a year
# 293                                 Gahanna, OH              $60,000 a year
# 294                                 Gahanna, OH              $60,000 a year
# 296                                 Gahanna, OH              $60,000 a year
# 298                                 Gahanna, OH              $60,000 a year
# 300                                 Gahanna, OH              $60,000 a year
# 302                                 Gahanna, OH              $60,000 a year
# 308                                 Gahanna, OH              $60,000 a year
# 311                                 Gahanna, OH              $60,000 a year
# 314                                 Gahanna, OH              $60,000 a year
# 318                                 Gahanna, OH              $60,000 a year
# 320                                 Gahanna, OH              $60,000 a year
# 321                                 Gahanna, OH              $60,000 a year
# 322                                 Gahanna, OH              $60,000 a year
# 323                                 Gahanna, OH              $60,000 a year
# 329                                 Gahanna, OH              $60,000 a year
# 330                                 Gahanna, OH              $60,000 a year
#
#                                            description  rating  remote  \
# 2    Develops and maintains data sets used by Count...     3.6   False
# 3    To be an expert to guide the team to explore a...     3.6   False
# 4    Develops and maintains data sets used by Count...     3.6   False
# 6    Leverages data in the University data warehous...     4.2   False
# 13   You’ll report directly to Triplebytes' Head of...     5.0    True
# 17   Builds and maintains professional relationship...     4.2   False
# 19   Documents data flow diagrams, security access,...     NaN   False
# 23   Builds and maintains professional relationship...     4.2   False
# 24   Your primary focus will be the development of ...     NaN   False
# 28   Documents data flow diagrams, security access,...     NaN   False
# 29   Advanced degree in a data science equivalent f...     3.8   False
# 30   Develop and move code in our production enviro...     NaN   False
# 31   Develop and move code in our production enviro...     NaN   False
# 32   Your primary focus will be the development of ...     NaN   False
# 34   Experience in predictive modeling, data scienc...     NaN   False
# 37   3+ year professional data science or software ...     4.2   False
# 40   These analysts identify and collect data from ...     4.2   False
# 41   This includes designing how the data will be s...     4.3   False
# 43   These analysts identify and collect data from ...     4.2   False
# 45   These analysts identify and collect data from ...     4.2   False
# 47   These analysts identify and collect data from ...     4.2   False
# 48   Strongbackground in data structures, algorithm...     NaN   False
# 50   These analysts identify and collect data from ...     4.2   False
# 51   Experience with Data Visualization libraries (...     NaN   False
# 53   These analysts identify and collect data from ...     4.2   False
# 54   Experience with Data Visualization libraries (...     NaN   False
# 55   Strongbackground in data structures, algorithm...     NaN   False
# 57   These analysts identify and collect data from ...     4.2   False
# 58   Strongbackground in data structures, algorithm...     NaN   False
# 60   Strongbackground in data structures, algorithm...     NaN   False
# ..                                                 ...     ...     ...
# 267  Strongbackground in data structures, algorithm...     NaN   False
# 268  Strongbackground in data structures, algorithm...     NaN   False
# 269  Strongbackground in data structures, algorithm...     NaN   False
# 270  Strongbackground in data structures, algorithm...     NaN   False
# 271  Strongbackground in data structures, algorithm...     NaN   False
# 272  Strongbackground in data structures, algorithm...     NaN   False
# 273  Strongbackground in data structures, algorithm...     NaN   False
# 274  Strongbackground in data structures, algorithm...     NaN   False
# 277  Strongbackground in data structures, algorithm...     NaN   False
# 280  Strongbackground in data structures, algorithm...     NaN   False
# 281  Strongbackground in data structures, algorithm...     NaN   False
# 283  Strongbackground in data structures, algorithm...     NaN   False
# 284  Strongbackground in data structures, algorithm...     NaN   False
# 287  Strongbackground in data structures, algorithm...     NaN   False
# 293  Strongbackground in data structures, algorithm...     NaN   False
# 294  Strongbackground in data structures, algorithm...     NaN   False
# 296  Strongbackground in data structures, algorithm...     NaN   False
# 298  Strongbackground in data structures, algorithm...     NaN   False
# 300  Strongbackground in data structures, algorithm...     NaN   False
# 302  Strongbackground in data structures, algorithm...     NaN   False
# 308  Strongbackground in data structures, algorithm...     NaN   False
# 311  Strongbackground in data structures, algorithm...     NaN   False
# 314  Strongbackground in data structures, algorithm...     NaN   False
# 318  Strongbackground in data structures, algorithm...     NaN   False
# 320  Strongbackground in data structures, algorithm...     NaN   False
# 321  Strongbackground in data structures, algorithm...     NaN   False
# 322  Strongbackground in data structures, algorithm...     NaN   False
# 323  Strongbackground in data structures, algorithm...     NaN   False
# 329  Strongbackground in data structures, algorithm...     NaN   False
# 330  Strongbackground in data structures, algorithm...     NaN   False
#
#      Salary_year  Salary_quant
# 2        61120.5       61120.5
# 3       100352.5      100352.5
# 4        61120.5       61120.5
# 6        71728.5       71728.5
# 13      185000.0      185000.0
# 17       99206.5       99206.5
# 19       81931.0       81931.0
# 23       99206.5       99206.5
# 24      125000.0      125000.0
# 28       81931.0       81931.0
# 29       97015.0       97015.0
# 30      160000.0      160000.0
# 31      160000.0      160000.0
# 32      125000.0      125000.0
# 34      124800.0      124800.0
# 37       87500.0       87500.0
# 40       99206.5       99206.5
# 41      111009.5      111009.5
# 43       99206.5       99206.5
# 45       99206.5       99206.5
# 47       99206.5       99206.5
# 48       60000.0       60000.0
# 50       99206.5       99206.5
# 51      156000.0      156000.0
# 53       99206.5       99206.5
# 54      156000.0      156000.0
# 55       60000.0       60000.0
# 57       99206.5       99206.5
# 58       60000.0       60000.0
# 60       60000.0       60000.0
# ..           ...           ...
# 267      60000.0       60000.0
# 268      60000.0       60000.0
# 269      60000.0       60000.0
# 270      60000.0       60000.0
# 271      60000.0       60000.0
# 272      60000.0       60000.0
# 273      60000.0       60000.0
# 274      60000.0       60000.0
# 277      60000.0       60000.0
# 280      60000.0       60000.0
# 281      60000.0       60000.0
# 283      60000.0       60000.0
# 284      60000.0       60000.0
# 287      60000.0       60000.0
# 293      60000.0       60000.0
# 294      60000.0       60000.0
# 296      60000.0       60000.0
# 298      60000.0       60000.0
# 300      60000.0       60000.0
# 302      60000.0       60000.0
# 308      60000.0       60000.0
# 311      60000.0       60000.0
# 314      60000.0       60000.0
# 318      60000.0       60000.0
# 320      60000.0       60000.0
# 321      60000.0       60000.0
# 322      60000.0       60000.0
# 323      60000.0       60000.0
# 329      60000.0       60000.0
# 330      60000.0       60000.0
#
# [192 rows x 9 columns]

# %%
median_quant=df2['Salary_quant'].median()

# %%
d={}

# %%
d['median_quant']=median_quant

# %%
median_quant
# Out:
# 66424.5

# %%
list_median.append(d)

# %%
df_data_science.sample(10)
# Out:
#                                               position  \
# 348   Information Technology Specialist (Data Science)
# 195                                      Data Engineer
# 28                        Data Engineer/ ETL Developer
# 155                                       Data Analyst
# 127  Senior Director, Trusted Artificial Intelligen...
# 69   Senior Director, Trusted Artificial Intelligen...
# 3                                  Data Scientist\nnew
# 273                                      Data Engineer
# 323                                      Data Engineer
# 83                                        Data Analyst
#
#                                     company  \
# 348                  US Department of Labor
# 195                               Kognetics
# 28                              SDH Systems
# 155                US Department of Defense
# 127                Liberty Mutual Insurance
# 69                 Liberty Mutual Insurance
# 3    Government of the District of Columbia
# 273                               Kognetics
# 323                               Kognetics
# 83                 US Department of Defense
#
#                                        location                      salary  \
# 348                              Washington, DC  $121,316 - $157,709 a year
# 195                                 Gahanna, OH              $60,000 a year
# 28                Chicago, IL 60604 (Loop area)              $81,931 a year
# 155                               St. Louis, MO   $64,948 - $133,465 a year
# 127                            Boston, MA 02101  $166,000 - $219,000 a year
# 69                             Boston, MA 02101  $166,000 - $219,000 a year
# 3    Washington, DC 20002 (Truxton Circle area)   $87,703 - $113,002 a year
# 273                                 Gahanna, OH              $60,000 a year
# 323                                 Gahanna, OH              $60,000 a year
# 83                                St. Louis, MO   $64,948 - $133,465 a year
#
#                                            description  rating  remote
# 348  This position leads data science projects spec...     4.0   False
# 195  Strongbackground in data structures, algorithm...     NaN   False
# 28   Documents data flow diagrams, security access,...     NaN   False
# 155  These analysts identify and collect data from ...     4.2   False
# 127  Expert knowledge of data science and machine l...     3.6   False
# 69   Expert knowledge of data science and machine l...     3.6   False
# 3    To be an expert to guide the team to explore a...     3.6   False
# 273  Strongbackground in data structures, algorithm...     NaN   False
# 323  Strongbackground in data structures, algorithm...     NaN   False
# 83   These analysts identify and collect data from ...     4.2   False

# %%
filt=df_data_science['position'].str.match('Data Scientist')

# %%
df2=df_data_science.loc[filt]
df2
# Out:
#                         position  \
# 3            Data Scientist\nnew
# 6         Data Scientist II\nnew
# 13           Data Scientist\nnew
# 17                Data Scientist
# 23                Data Scientist
# 29                Data Scientist
# 34  Data Scientist (Health Care)
#
#                                             company  \
# 3            Government of the District of Columbia
# 6                            University of Kentucky
# 13                                       Triplebyte
# 17                         US Department of Defense
# 23                         US Department of Defense
# 29  US Other Agencies and Independent Organizations
# 34                                    Ace-stack LLC
#
#                                       location                      salary  \
# 3   Washington, DC 20002 (Truxton Circle area)   $87,703 - $113,002 a year
# 6                                Lexington, KY    $54,142 - $89,315 a year
# 13                                 Seattle, WA  $145,000 - $225,000 a year
# 17                               St. Louis, MO   $64,948 - $133,465 a year
# 23                               St. Louis, MO   $64,948 - $133,465 a year
# 29                              Washington, DC   $67,968 - $126,062 a year
# 34                              Washington, DC                 $60 an hour
#
#                                           description  rating  remote
# 3   To be an expert to guide the team to explore a...     3.6   False
# 6   Leverages data in the University data warehous...     4.2   False
# 13  You’ll report directly to Triplebytes' Head of...     5.0    True
# 17  Builds and maintains professional relationship...     4.2   False
# 23  Builds and maintains professional relationship...     4.2   False
# 29  Advanced degree in a data science equivalent f...     3.8   False
# 34  Experience in predictive modeling, data scienc...     NaN   False

# %%
df2['Salary_year']=df2['salary'].map(standardized)
# Out:
# $87,703 - $113,002 a year
# $54,142 - $89,315 a year
# $145,000 - $225,000 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $67,968 - $126,062 a year
# $60 an hour
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df2
# Out:
#                         position  \
# 3            Data Scientist\nnew
# 6         Data Scientist II\nnew
# 13           Data Scientist\nnew
# 17                Data Scientist
# 23                Data Scientist
# 29                Data Scientist
# 34  Data Scientist (Health Care)
#
#                                             company  \
# 3            Government of the District of Columbia
# 6                            University of Kentucky
# 13                                       Triplebyte
# 17                         US Department of Defense
# 23                         US Department of Defense
# 29  US Other Agencies and Independent Organizations
# 34                                    Ace-stack LLC
#
#                                       location                      salary  \
# 3   Washington, DC 20002 (Truxton Circle area)   $87,703 - $113,002 a year
# 6                                Lexington, KY    $54,142 - $89,315 a year
# 13                                 Seattle, WA  $145,000 - $225,000 a year
# 17                               St. Louis, MO   $64,948 - $133,465 a year
# 23                               St. Louis, MO   $64,948 - $133,465 a year
# 29                              Washington, DC   $67,968 - $126,062 a year
# 34                              Washington, DC                 $60 an hour
#
#                                           description  rating  remote  \
# 3   To be an expert to guide the team to explore a...     3.6   False
# 6   Leverages data in the University data warehous...     4.2   False
# 13  You’ll report directly to Triplebytes' Head of...     5.0    True
# 17  Builds and maintains professional relationship...     4.2   False
# 23  Builds and maintains professional relationship...     4.2   False
# 29  Advanced degree in a data science equivalent f...     3.8   False
# 34  Experience in predictive modeling, data scienc...     NaN   False
#
#     Salary_year
# 3      100352.5
# 6       71728.5
# 13     185000.0
# 17      99206.5
# 23      99206.5
# 29      97015.0
# 34     124800.0

# %%
data_scientist_salary=df2['Salary_year'].median()

# %%
list_median.append(data_scientist_salary)

# %%
list_median.remove(99206.5)

# %%
d={}

# %%
d['data_scientist_salary']=data_scientist_salary

# %%
list_median.append(d)

# %%
list_median
# Out:
# [{'median_quant': 66424.5}, {'data_scientist_salary': 99206.5}]

# %%
filt=df_data_science['position'].str.match('Data')

# %%
df2=df_data_science.loc[filt]

# %%
df2['Salary_year']=df2['salary'].map(standardized)
# Out:
# $49,381 - $72,860 a year
# $87,703 - $113,002 a year
# $49,381 - $72,860 a year
# $54,142 - $89,315 a year
# $145,000 - $225,000 a year
# $64,948 - $133,465 a year
# $81,931 a year
# $64,948 - $133,465 a year
# $100,000 - $150,000 a year
# $81,931 a year
# $67,968 - $126,062 a year
# $150,000 - $170,000 a year
# $150,000 - $170,000 a year
# $100,000 - $150,000 a year
# $60 an hour
# $85,000 - $90,000 a year
# $64,948 - $133,465 a year
# $73,052 - $148,967 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $60,000 a year
# $64,948 - $133,465 a year
# $75 an hour
# $64,948 - $133,465 a year
# $75 an hour
# $60,000 a year
# $64,948 - $133,465 a year
# $60,000 a year
# $60,000 a year
# $75 an hour
# $60,000 a year
# $64,948 - $133,465 a year
# $75 an hour
# $75 an hour
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $60,000 a year
# $64,948 - $133,465 a year
# $60,000 a year
# $75 an hour
# $75 an hour
# $75 an hour
# $60,000 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $75 an hour
# $75 an hour
# $75 an hour
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $60,000 a year
# $60,000 a year
# $75 an hour
# $75 an hour
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $60,000 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $60,000 a year
# $64,948 - $133,465 a year
# $75 an hour
# $60,000 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $60,000 a year
# $60,000 a year
# $75 an hour
# $60,000 a year
# $75 an hour
# $60,000 a year
# $64,948 - $133,465 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $75 an hour
# $64,948 - $133,465 a year
# $75 an hour
# $60,000 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $75 an hour
# $64,948 - $133,465 a year
# $60,000 a year
# $64,948 - $133,465 a year
# $75 an hour
# $75 an hour
# $64,948 - $133,465 a year
# $75 an hour
# $64,948 - $133,465 a year
# $75 an hour
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $75 an hour
# $60,000 a year
# $75 an hour
# $75 an hour
# $64,948 - $133,465 a year
# $75 an hour
# $64,948 - $133,465 a year
# $75 an hour
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $64,948 - $133,465 a year
# $60,000 a year
# $64,948 - $133,465 a year
# $75 an hour
# $60,000 a year
# $64,948 - $133,465 a year
# $75 an hour
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# $60,000 a year
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df2['Salary_year'].median()
# Out:
# 66424.5

# %%
d={}

# %%
d['data_analyst']=df2['Salary_year'].median()

# %%
list_median.append(d)

# %%
list_median
# Out:
# [{'median_quant': 66424.5},
#  {'data_scientist_salary': 99206.5},
#  {'data_analyst': 66424.5}]

# %%
l=(list_median[1:])
l
# Out:
# [{'data_scientist_salary': 99206.5}, {'data_analyst': 66424.5}]

# %%
poisitons=[l[0].keys(),l[1].keys()]
salariess=[l[0].values(),l[1].values()]

# %%
poisitons=list(poisitons)
poisiton=[]
for x in poisitons:
    poisiton.extend(list(x))

# %%
salaries=[]
for x in salariess:
    salaries.extend(list(x))

# %%
poisiton
# Out:
# ['data_scientist_salary', 'data_analyst']

# %%
width=0.5
plt.style.use('ggplot')
plt.bar(poisiton, salaries, color="#e5ae38",width=width)


plt.title('Data Scientist vs Data Analyst')
plt.ylabel('meidan salary USD')

plt.show()

# %%
list_median
# Out:
# [{'median_quant': 66424.5},
#  {'data_scientist_salary': 99206.5},
#  {'data_analyst': 66424.5}]

# %%
df_back_end.sample(10)
# Out:
#                   position                     company  \
# 176        Java Developers                   Integrass
# 177        Java Developers                   Integrass
# 17       Junior Strategist              Chong & Koster
# 97        Senior Developer             Piper Companies
# 88        Senior Developer             Piper Companies
# 65        Senior Developer             Piper Companies
# 34         Java Developers                   Integrass
# 243  Scientific Programmer       University at Buffalo
# 159       Senior Developer             Piper Companies
# 240         Java Developer  SUNY System Administration
#
#                                       location                     salary  \
# 176                        Lake Mary, FL 32746                $65 an hour
# 177                        Lake Mary, FL 32746                $65 an hour
# 17   Washington, DC 20036 (Dupont Circle area)   $50,000 - $54,000 a year
# 97                                  Durham, NC  $90,000 - $115,000 a year
# 88                                  Durham, NC  $90,000 - $115,000 a year
# 65                                  Durham, NC  $90,000 - $115,000 a year
# 34                         Lake Mary, FL 32746                $65 an hour
# 243                          Buffalo, NY 14260   $60,000 - $95,000 a year
# 159                                 Durham, NC  $90,000 - $115,000 a year
# 240                           Albany, NY 12207        From $50,000 a year
#
#                                            description  rating  remote
# 176  Java back end or full-stack,.\nJob Type - 12 M...     NaN   False
# 177  Java back end or full-stack,.\nJob Type - 12 M...     NaN   False
# 17   Experience using or setting up back-end CRM pl...     NaN   False
# 97   Experience with designing application front-en...     4.4   False
# 88   Experience with designing application front-en...     4.4   False
# 65   Experience with designing application front-en...     4.4   False
# 34   Java back end or full-stack,.\nJob Type - 12 M...     NaN   False
# 243  The ideal candidate will be a full stack devel...     4.3   False
# 159  Experience with designing application front-en...     4.4   False
# 240  The system is primarily developed in Java with...     3.2   False

# %%
df_back_end['Salary_year']=df_back_end['salary'].map(standardized)
# Out:
# $90,000 - $110,000 a year
# $35 an hour
# $120,000 a year
# $60 an hour
# $60 an hour
# $95,000 - $105,000 a year
# $95,000 - $105,000 a year
# $80,000 - $120,000 a year
# $57,757 - $97,843 a year
# $57,757 - $97,843 a year
# $80,000 - $120,000 a year
# $80,000 - $120,000 a year
# $16 an hour
# $100,000 a year
# $150,000 - $175,000 a year
# $16 an hour
# $16 an hour
# $50,000 - $54,000 a year
# $29.75 - $46.13 an hour
# $30 - $45 an hour
# $80,000 - $130,000 a year
# $58,582 a year
# $5,259 - $8,624 a month
# $30 - $45 an hour
# $90,000 - $110,000 a year
# $30 - $35 an hour
# $120,000 - $170,000 a year
# $65 an hour
# $65 an hour
# $500,000 a year
# $65 an hour
# $11 - $15 an hour
# $100,000 - $115,000 a year
# $115,000 a year
# $65 an hour
# $91,231 - $124,955 a year
# $500,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $65 an hour
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $65 an hour
# $90,000 - $115,000 a year
# $65 an hour
# $65 an hour
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $65 an hour
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $65 an hour
# $90,000 - $115,000 a year
# $65 an hour
# $90,000 - $115,000 a year
# $65 an hour
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $65 an hour
# $65 an hour
# $65 an hour
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $65 an hour
# $90,000 - $115,000 a year
# $65 an hour
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $65 an hour
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $65 an hour
# $65 an hour
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $65 an hour
# $65 an hour
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $65 an hour
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $65 an hour
# $65 an hour
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $65 an hour
# $65 an hour
# $90,000 - $115,000 a year
# $65 an hour
# $90,000 - $115,000 a year
# $65 an hour
# $90,000 - $115,000 a year
# $65 an hour
# $65 an hour
# $65 an hour
# $90,000 - $115,000 a year
# $90,000 - $115,000 a year
# $65 an hour
# $90,000 - $115,000 a year
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $60,000 - $95,000 a year
# $60,000 - $95,000 a year
# $60,000 - $95,000 a year
# $60,000 - $95,000 a year
# $60,000 - $95,000 a year
# $60,000 - $95,000 a year
# $60,000 - $95,000 a year
# $60,000 - $95,000 a year
# $60,000 - $95,000 a year
# $60,000 - $95,000 a year
# $60,000 - $95,000 a year
# $60,000 - $95,000 a year
# $60,000 - $95,000 a year
# $60,000 - $95,000 a year
# $60,000 - $95,000 a year
# $60,000 - $95,000 a year
# $60,000 - $95,000 a year
# $60,000 - $95,000 a year
# $60,000 - $95,000 a year
# $55,000 - $70,000 a year
# $55,000 - $70,000 a year
# $55,000 - $70,000 a year
# $55,000 - $70,000 a year
# $55,000 - $70,000 a year
# $55,000 - $70,000 a year
# $55,000 - $70,000 a year
# $55,000 - $70,000 a year
# $55,000 - $70,000 a year
# $55,000 - $70,000 a year
# $55,000 - $70,000 a year
# $55,000 - $70,000 a year
# $55,000 - $70,000 a year
# $55,000 - $70,000 a year
# $55,000 - $70,000 a year
# $55,000 - $70,000 a year
# $55,000 - $70,000 a year
# $55,000 - $70,000 a year
# $55,000 - $70,000 a year
# $55,000 - $70,000 a year
# $55,000 - $70,000 a year
# $55,000 - $70,000 a year
# $55,000 - $70,000 a year
# $55,000 - $70,000 a year
# $55,000 - $70,000 a year

# %%
df_back_end['Salary_year'].median()
# Out:
# 102500.0

# %%
d={}
d['back_end']=df_back_end['Salary_year'].median()

# %%
list_median.append(d)

# %%
list_median
# Out:
# [{'median_quant': 66424.5},
#  {'data_scientist_salary': 99206.5},
#  {'data_analyst': 66424.5},
#  {'back_end': 102500.0}]

# %%
df_web_deb.head(10)
# Out:
#                                     position                  company  \
# 0  Junior Web Designer & Front-End Developer             Fame Foundry
# 1                         Web Developer\nnew             UC San Diego
# 2                         Web Developer\nnew             UC San Diego
# 3                  Web Application Developer    Utah State University
# 4                    Front End Web Developer     Texas A&M University
# 5                   Full Stack Web Developer                 KinaTrax
# 6                              Web Developer                Tire Guru
# 7                     Jr. Web Developer\nnew              WebFX, Inc.
# 8               Front-End Web Developer\nnew                    Mondo
# 9                         Web Developer\nnew  State of North Carolina
#
#                                    location                     salary  \
# 0  Charlotte, NC 28210 (Beverly Woods area)   $40,000 - $50,000 a year
# 1                             San Diego, CA   $59,700 - $95,000 a year
# 2                             San Diego, CA   $59,700 - $95,000 a year
# 3          Logan, UT 84322 (Hillcrest area)                $65 an hour
# 4                 College Station, TX 77840   $38,647 - $45,198 a year
# 5                                   MISSING  $80,000 - $120,000 a year
# 6                           Logan, UT 84321           From $12 an hour
# 7       Harrisburg, PA 17102 (Midtown area)   $47,000 - $52,000 a year
# 8     Denver, CO 80202 (Union Station area)                $35 an hour
# 9                           Wake County, NC   $56,339 - $91,817 a year
#
#                                          description  rating  remote
# 0  Expert knowledge of HTML5/DOM, CSS3, Javascrip...     NaN    True
# 1  Work experience in web application development...     4.2   False
# 2  Work experience in web application development...     4.2   False
# 3  Construct aesthetic leaflet maps that will be ...     4.3    True
# 4  Writes and modifies front-end code in applicab...     4.4   False
# 5  Designing user interactions on web pages.\nSta...     NaN    True
# 6  Working with other team members to create web ...     NaN   False
# 7  Our “Bootcamp” web marketing training program ...     4.7   False
# 8  Proficient understanding of web markup, includ...     NaN   False
# 9  This position is in the Public Safety Division...     3.5   False

# %%
df_web_deb['Salary_year']=df_web_deb['salary'].map(standardized)
# Out:
# $40,000 - $50,000 a year
# $59,700 - $95,000 a year
# $59,700 - $95,000 a year
# $65 an hour
# $38,647 - $45,198 a year
# $80,000 - $120,000 a year
# $47,000 - $52,000 a year
# $35 an hour
# $56,339 - $91,817 a year
# $40,000 - $60,000 a year
# $56,339 - $91,817 a year
# $66,000 a year
# $90,000 a year
# $57,757 - $97,843 a year
# $80,000 a year
# $55,000 a year
# $13 an hour
# $5,407 - $8,111 a month
# $73,261 a year
# $40,759 - $75,413 a year
# $90,000 a year
# $73,261 a year
# $40,759 - $75,413 a year
# $16 an hour
# $55,000 - $65,000 a year
# $70,000 - $110,000 a year
# $40,000 - $100,000 a year
# $1,000 a month
# $67,724 a year
# $59,694 - $77,603 a year
# $55,000 - $65,000 a year
# $40,000 - $60,000 a year
# $110,000 a year
# $25 an hour
# $70,000 - $110,000 a year
# $55,000 - $65,000 a year
# $20 - $25 an hour
# $25 an hour
# $110,000 a year
# $40,000 - $60,000 a year
# $40,000 - $60,000 a year
# $50,000 a year
# $40,000 - $60,000 a year
# $92,000 a year
# $52,529 a year
# $65,000 - $75,000 a year
# $75,000 - $120,000 a year
# $50,000 - $80,000 a year
# $11 - $15 an hour
# $60 an hour
# $20 - $25 an hour
# $45 - $65 an hour
# $95,000 - $105,000 a year
# $58,582 a year
# $100,000 - $115,000 a year
# $50,000 - $55,000 a year
# $40,000 - $60,000 a year
# $65 - $75 an hour
# $51,500 a year
# $64,341 a year
# $45,000 - $65,000 a year
# $100,000 a year
# $80,000 - $90,000 a year
# $80,000 - $90,000 a year
# $93,000 a year
# $70,000 a year
# $6,000 - $9,500 a month
# $80,000 a year
# $60 an hour
# $40,759 a year
# $50 an hour
# $95,000 - $105,000 a year
# $58,582 a year
# $70,000 - $90,000 a year
# $96,000 a year
# $70,000 - $90,000 a year
# $96,000 a year
# $50,000 - $55,000 a year
# $64,341 a year
# $70,000 - $90,000 a year
# $96,000 a year
# $70,000 - $90,000 a year
# $96,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $96,000 a year
# $70,000 - $90,000 a year
# $96,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $96,000 a year
# $96,000 a year
# $70,000 - $90,000 a year
# $96,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $96,000 a year
# $55,000 a year
# $70,000 - $90,000 a year
# $96,000 a year
# $70,000 - $90,000 a year
# $55,000 a year
# $70,000 - $90,000 a year
# $55,000 a year
# $96,000 a year
# $70,000 - $90,000 a year
# $96,000 a year
# $70,000 - $90,000 a year
# $55,000 a year
# $70,000 - $90,000 a year
# $96,000 a year
# $96,000 a year
# $96,000 a year
# $70,000 - $90,000 a year
# $55,000 a year
# $55,000 a year
# $96,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $96,000 a year
# $55,000 a year
# $70,000 - $90,000 a year
# $96,000 a year
# $70,000 - $90,000 a year
# $96,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $96,000 a year
# $70,000 - $90,000 a year
# $96,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $96,000 a year
# $96,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $96,000 a year
# $55,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $96,000 a year
# $70,000 - $90,000 a year
# $96,000 a year
# $55,000 a year
# $55,000 a year
# $70,000 - $90,000 a year
# $96,000 a year
# $70,000 - $90,000 a year
# $55,000 a year
# $70,000 - $90,000 a year
# $55,000 a year
# $70,000 - $90,000 a year
# $96,000 a year
# $70,000 - $90,000 a year
# $96,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $96,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $50,000 - $70,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $50,000 - $70,000 a year
# $70,000 - $90,000 a year
# $50,000 - $70,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $50,000 - $70,000 a year
# $70,000 - $90,000 a year
# $50,000 - $70,000 a year
# $50,000 - $70,000 a year
# $50,000 - $70,000 a year
# $50,000 - $70,000 a year
# $50,000 - $70,000 a year
# $50,000 - $70,000 a year
# $50,000 - $70,000 a year
# $50,000 - $70,000 a year
# $70,000 - $90,000 a year
# $50,000 - $70,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $50,000 - $70,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $50,000 - $70,000 a year
# $70,000 - $90,000 a year
# $50,000 - $70,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $50,000 - $70,000 a year
# $50,000 - $70,000 a year
# $50,000 - $70,000 a year
# $50,000 - $70,000 a year
# $50,000 - $70,000 a year
# $70,000 - $90,000 a year
# $50,000 - $70,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $50,000 - $70,000 a year
# $70,000 - $90,000 a year
# $50,000 - $70,000 a year
# $70,000 - $90,000 a year
# $70,000 - $90,000 a year
# $50,000 - $70,000 a year
# $70,000 - $90,000 a year
# $50,000 - $70,000 a year
# $50,000 - $70,000 a year
# $50,000 - $70,000 a year
# $70,000 - $90,000 a year
# $50,000 - $70,000 a year
# $50,000 - $70,000 a year
# $50,000 - $70,000 a year
# $50,000 - $70,000 a year
# $70,000 - $90,000 a year
# $50,000 - $70,000 a year
# $92,159 - $119,810 a year
# $92,159 - $119,810 a year
# $70,000 - $90,000 a year

# %%
df_web_deb.head(10)
# Out:
#                                     position                  company  \
# 0  Junior Web Designer & Front-End Developer             Fame Foundry
# 1                         Web Developer\nnew             UC San Diego
# 2                         Web Developer\nnew             UC San Diego
# 3                  Web Application Developer    Utah State University
# 4                    Front End Web Developer     Texas A&M University
# 5                   Full Stack Web Developer                 KinaTrax
# 6                              Web Developer                Tire Guru
# 7                     Jr. Web Developer\nnew              WebFX, Inc.
# 8               Front-End Web Developer\nnew                    Mondo
# 9                         Web Developer\nnew  State of North Carolina
#
#                                    location                     salary  \
# 0  Charlotte, NC 28210 (Beverly Woods area)   $40,000 - $50,000 a year
# 1                             San Diego, CA   $59,700 - $95,000 a year
# 2                             San Diego, CA   $59,700 - $95,000 a year
# 3          Logan, UT 84322 (Hillcrest area)                $65 an hour
# 4                 College Station, TX 77840   $38,647 - $45,198 a year
# 5                                   MISSING  $80,000 - $120,000 a year
# 6                           Logan, UT 84321           From $12 an hour
# 7       Harrisburg, PA 17102 (Midtown area)   $47,000 - $52,000 a year
# 8     Denver, CO 80202 (Union Station area)                $35 an hour
# 9                           Wake County, NC   $56,339 - $91,817 a year
#
#                                          description  rating  remote  \
# 0  Expert knowledge of HTML5/DOM, CSS3, Javascrip...     NaN    True
# 1  Work experience in web application development...     4.2   False
# 2  Work experience in web application development...     4.2   False
# 3  Construct aesthetic leaflet maps that will be ...     4.3    True
# 4  Writes and modifies front-end code in applicab...     4.4   False
# 5  Designing user interactions on web pages.\nSta...     NaN    True
# 6  Working with other team members to create web ...     NaN   False
# 7  Our “Bootcamp” web marketing training program ...     4.7   False
# 8  Proficient understanding of web markup, includ...     NaN   False
# 9  This position is in the Public Safety Division...     3.5   False
#
#    Salary_year
# 0      45000.0
# 1      77350.0
# 2      77350.0
# 3     135200.0
# 4      41922.5
# 5     100000.0
# 6          NaN
# 7      49500.0
# 8      72800.0
# 9      74078.0

# %%
df_web_deb['Salary_year'].median()
# Out:
# 80000.0

# %%
d={}
d['df_web_deb']=df_web_deb['Salary_year'].median()
list_median.append(d)

# %%
list_median
# Out:
# [{'median_quant': 66424.5},
#  {'data_scientist_salary': 99206.5},
#  {'data_analyst': 66424.5},
#  {'back_end': 102500.0},
#  {'df_web_deb': 80000.0}]

# %%
list_median
# Out:
# [{'median_quant': 66424.5},
#  {'data_scientist_salary': 99206.5},
#  {'data_analyst': 66424.5},
#  {'back_end': 102500.0},
#  {'df_web_deb': 80000.0}]

# %%
df_front_end.head(5)
# Out:
#                                     position               company  \
# 0  Junior Web Designer & Front-End Developer          Fame Foundry
# 1                    Front End Web Developer  Texas A&M University
# 2                        Front End Developer   Authentic Campaigns
# 3               Front-End Web Developer\nnew                 Mondo
# 4                        Front End Developer   Authentic Campaigns
#
#                                    location                    salary  \
# 0  Charlotte, NC 28210 (Beverly Woods area)  $40,000 - $50,000 a year
# 1                 College Station, TX 77840  $38,647 - $45,198 a year
# 2                             United States            $80,000 a year
# 3     Denver, CO 80202 (Union Station area)               $35 an hour
# 4                             United States            $80,000 a year
#
#                                          description  rating  remote
# 0  2-4+ years of demonstrated professional experi...     NaN    True
# 1  Works with software application developers to ...     4.4   False
# 2  Develop WordPress themes and any associated fr...     NaN    True
# 3  Develop new user-facing features.\nBuild reusa...     NaN   False
# 4  Develop WordPress themes and any associated fr...     NaN    True

# %%
df_front_end['Salary_year']=df_front_end['salary'].map(standardized)
# Out:
# $40,000 - $50,000 a year
# $38,647 - $45,198 a year
# $80,000 a year
# $35 an hour
# $80,000 a year
# $35 an hour
# $60 an hour
# $105,000 - $125,000 a year
# $95,000 - $105,000 a year
# $100,000 - $125,000 a year
# $65 an hour
# $70,000 - $90,000 a year
# $47,000 - $52,000 a year
# $105,000 - $125,000 a year
# $115,000 a year
# $70,000 - $90,000 a year
# $112,000 - $134,000 a year
# $59,700 - $95,000 a year
# $115,000 a year
# $56,339 - $91,817 a year
# $65 an hour
# $66,000 a year
# $65 an hour
# $65 an hour
# $40,000 - $60,000 a year
# $80,000 - $120,000 a year
# $95,000 a year
# $45 - $65 an hour
# $55,000 a year
# $60 an hour
# $56,339 - $91,817 a year
# $67,724 a year
# $80,000 - $120,000 a year
# $40,759 - $75,413 a year
# $16 an hour
# $80,000 - $90,000 a year
# $45 - $65 an hour
# $10.62 an hour
# $25 an hour
# $25 an hour
# $10.62 an hour
# $12 - $15 an hour
# $60 an hour
# $60 an hour
# $60 an hour
# $73,261 a year
# $80,000 - $110,000 a year
# $59,694 - $77,603 a year
# $67,724 a year
# $5,407 - $8,111 a month
# $16 an hour
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $1,000 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $59,694 - $77,603 a year
# $75,000 a year
# $59,694 - $77,603 a year
# $75,000 a year
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $65 an hour
# $5,407 - $8,111 a month
# $65 an hour
# $65 an hour
# $65 an hour
# $5,407 - $8,111 a month
# $65 an hour
# $5,407 - $8,111 a month
# $65 an hour
# $5,407 - $8,111 a month
# $65 an hour
# $65 an hour
# $5,407 - $8,111 a month
# $65 an hour
# $65 an hour
# $5,407 - $8,111 a month
# $65 an hour
# $5,407 - $8,111 a month
# $65 an hour
# $5,407 - $8,111 a month
# $65 an hour
# $5,407 - $8,111 a month
# $65 an hour
# $5,407 - $8,111 a month
# $65 an hour
# $65 an hour
# $5,407 - $8,111 a month
# $65 an hour
# $65 an hour
# $65 an hour
# $65 an hour
# $5,407 - $8,111 a month
# $65 an hour
# $65 an hour
# $65 an hour
# $5,407 - $8,111 a month
# $65 an hour
# $5,407 - $8,111 a month
# $65 an hour
# $5,407 - $8,111 a month
# $65 an hour
# $65 an hour
# $5,407 - $8,111 a month
# $65 an hour
# $5,407 - $8,111 a month
# $65 an hour
# $5,407 - $8,111 a month
# $65 an hour
# $5,407 - $8,111 a month
# $65 an hour
# $5,407 - $8,111 a month
# $65 an hour
# $5,407 - $8,111 a month
# $65 an hour
# $5,407 - $8,111 a month
# $65 an hour
# $5,407 - $8,111 a month
# $65 an hour
# $5,407 - $8,111 a month
# $65 an hour
# $5,407 - $8,111 a month
# $65 an hour
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $65 an hour
# $5,407 - $8,111 a month
# $65 an hour
# $5,407 - $8,111 a month
# $65 an hour
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $5,407 - $8,111 a month
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year
# $75,000 a year

# %%
df_front_end.head(5)
# Out:
#                                     position               company  \
# 0  Junior Web Designer & Front-End Developer          Fame Foundry
# 1                    Front End Web Developer  Texas A&M University
# 2                        Front End Developer   Authentic Campaigns
# 3               Front-End Web Developer\nnew                 Mondo
# 4                        Front End Developer   Authentic Campaigns
#
#                                    location                    salary  \
# 0  Charlotte, NC 28210 (Beverly Woods area)  $40,000 - $50,000 a year
# 1                 College Station, TX 77840  $38,647 - $45,198 a year
# 2                             United States            $80,000 a year
# 3     Denver, CO 80202 (Union Station area)               $35 an hour
# 4                             United States            $80,000 a year
#
#                                          description  rating  remote  \
# 0  2-4+ years of demonstrated professional experi...     NaN    True
# 1  Works with software application developers to ...     4.4   False
# 2  Develop WordPress themes and any associated fr...     NaN    True
# 3  Develop new user-facing features.\nBuild reusa...     NaN   False
# 4  Develop WordPress themes and any associated fr...     NaN    True
#
#    Salary_year
# 0      45000.0
# 1      41922.5
# 2      80000.0
# 3      72800.0
# 4      80000.0

# %%
df_front_end['Salary_year'].median()
# Out:
# 81108.0

# %%
d={}
d['df_front_end']=df_front_end['Salary_year'].median()
list_median.append(d)
list_median
# Out:
# [{'median_quant': 66424.5},
#  {'data_scientist_salary': 99206.5},
#  {'data_analyst': 66424.5},
#  {'back_end': 102500.0},
#  {'df_web_deb': 80000.0},
#  {'df_front_end': 81108.0}]

# %%
d={}

# %%
list_median
# Out:
# [{'median_quant': 66424.5},
#  {'data_scientist_salary': 99206.5},
#  {'data_analyst': 66424.5},
#  {'back_end': 102500.0},
#  {'df_web_deb': 80000.0},
#  {'df_front_end': 81108.0}]

# %%
list_median
# Out:
# [{'median_quant': 66424.5},
#  {'data_scientist_salary': 99206.5},
#  {'data_analyst': 66424.5},
#  {'back_end': 102500.0},
#  {'df_web_deb': 80000.0},
#  {'df_front_end': 81108.0}]

# %%
d=dict((key,d[key]) for d in list_median for key in d)
d
# Out:
# {'median_quant': 66424.5,
#  'data_scientist_salary': 99206.5,
#  'data_analyst': 66424.5,
#  'back_end': 102500.0,
#  'df_web_deb': 80000.0,
#  'df_front_end': 81108.0}

# %%
d['quant dev'] = d.pop('median_quant')
d
# Out:
# {'data_analyst': 66424.5,
#  'back_end': 102500.0,
#  'data_scientist': 99206.5,
#  'front_end': 81108.0,
#  'web_dev': 80000.0,
#  'quant dev': 66424.5}

# %%
d['data_scientist'] = d.pop('data_scientist_salary')

# %%
width=0.2
plt.style.use("ggplot")
plt.bar(d.keys(), d.values(), color="b",width=width)


plt.title('differents types of dev')
plt.ylabel('meidan salary USD')

plt.show()

# %%
######## 
# here

# %%
df3=pd.read_excel('education.xlsx')
df3
# Out:
#                                              Title      Firm Education Level
# 0                    Core Data Science, PhD Intern  Facebook             PhD
# 1                      Machine Learning Internship    Amazon            M.Sc
# 2  Data Engineer - Core Data Science & Engineering   Netflix            M.Sc
# 3          Data Scientist, PhD University Graduate    Google             PhD

# %%
edu_grp=df3.groupby(['Education Level'])

# %%
edu_grp['Firm']

# %%
PHD=edu_grp['Firm'].value_counts().loc['PhD'].value_counts()
PHD
# Out:
# 1    2
# Name: Firm, dtype: int64

# %%
MSC=edu_grp['Firm'].value_counts().loc['M.Sc'].value_counts()
MSC
# Out:
# 1    2
# Name: Firm, dtype: int64

# %%
edu_grp['Firm'].value_counts()
# Out:
# Education Level  Firm
# M.Sc             Amazon      1
#                  Netflix     1
# PhD              Facebook    1
#                  Google      1
# Name: Firm, dtype: int64

# %%
edu_grp.get_group('M.Sc')
# Out:
#                                              Title     Firm Education Level
# 1                      Machine Learning Internship   Amazon            M.Sc
# 2  Data Engineer - Core Data Science & Engineering  Netflix            M.Sc

# %%
l2=edu_grp.get_group('M.Sc')['Education Level']
d={}
d['M.Sc']=0
for x in l2:
    d[x]+=1

# %%
edu_grp.get_group('PhD')
# Out:
#                                      Title      Firm Education Level
# 0            Core Data Science, PhD Intern  Facebook             PhD
# 3  Data Scientist, PhD University Graduate    Google             PhD

# %%
l3=edu_grp.get_group('PhD')['Education Level']
d['PhD']=0
for x in l3:
    d[x]+=1
d
# Out:
# {'M.Sc': 2, 'PhD': 2}

# %%
plt.bar(d.keys(),d.values())
# Out:
# <BarContainer object of 2 artists>
